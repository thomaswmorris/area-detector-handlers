# %%
from area_detector_handlers import handlers

# %%
h = handlers.AreaDetectorHDF5Handler(filename='/users/thomas/desktop/nsls2/nbs/products/i_cam.h5')

# %%
h(0)
# Out:
# dask.array<getitem, shape=(1, 728, 968), dtype=uint16, chunksize=(1, 728, 968), chunktype=numpy.ndarray>

# %%
import matplotlib.pyplot as plt
plt.imshow(h._dataset.__array__()[0])

# %%
# Out:
# dask.array<getitem, shape=(1, 480, 704, 3), dtype=uint8, chunksize=(1, 480, 704, 3), chunktype=numpy.ndarray>

# %%
h(0).dask
# Out:
# HighLevelGraph with 2 layers.
# ...
#  0. array-f89409752bffcafab7a2af7918c50a8e
#  1. getitem-29e46435a649c481f260105afd7aae4d

# %%
list(h(0))
# Out:
# [dask.array<getitem, shape=(480, 704, 3), dtype=uint8, chunksize=(480, 704, 3), chunktype=numpy.ndarray>]

# %%
dir(h(0))
# Out:
# ['A',
#  'T',
#  '_Array__chunks',
#  '_Array__name',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_function__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__await__',
#  '__bool__',
#  '__class__',
#  '__complex__',
#  '__dask_graph__',
#  '__dask_keys__',
#  '__dask_layers__',
#  '__dask_optimize__',
#  '__dask_postcompute__',
#  '__dask_postpersist__',
#  '__dask_scheduler__',
#  '__dask_tokenize__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lshift__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
# ...

# %%
h(0).astype(float)
# Out:
# dask.array<astype, shape=(1, 480, 704, 3), dtype=float64, chunksize=(1, 480, 704, 3), chunktype=numpy.ndarray>

# %%
h(0)
# Out:
# dask.array<getitem, shape=(1, 480, 704, 3), dtype=uint8, chunksize=(1, 480, 704, 3), chunktype=numpy.ndarray>

# %%
from IPython.display import display, Image

# %%
h(0).visualize()
